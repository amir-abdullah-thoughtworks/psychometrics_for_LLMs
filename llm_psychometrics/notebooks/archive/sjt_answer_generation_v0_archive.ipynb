# %%
import pandas as pd
import os
import yaml
import sys
import json
import random
import hashlib
from itertools import product
import torch as t
from transformers import AutoTokenizer, AutoModelForCausalLM
from pydantic import BaseModel
import outlines
from outlines import Generator
from openai import OpenAI
from datasets import Dataset, load_dataset
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
from huggingface_hub import login
sys.path.append("../")
from src.utils import list_to_str, openai_api_call
device = "cpu"

# %%
class OpenaiResponse(BaseModel):
    response: str

def write_to_json(file, file_path):
    with open(file_path, 'w') as f:
        json.dump(file, f)
        
def read_json(file_path):
    with open(file_path, "r") as f:
        file = json.load(f)
    return file

# %%
synthetic_sjts = read_json('sjt_data/synthetic_generated_sjt_list.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 synthetic_sjts = read_json('sjt_data/synthetic_generated_sjt_list.json')
#
# Cell In[2], line 9, in read_json(file_path)
#       8 def read_json(file_path):
# ----> 9     with open(file_path, "r") as f:
#      10         file = json.load(f)
#      11     return file
#
# File ~/.pyenv/versions/3.11.9/envs/llm_psychometrics/lib/python3.11/site-packages/IPython/core/interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sjt_data/synthetic_generated_sjt_list.json'

# %%
login("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")

# %%
# Login using e.g. `huggingface-cli login` to access this dataset
hf_persona_dataset = load_dataset("thoughtworks/psychometric_personas_temp")
hf_persona_dataset = hf_persona_dataset['train']

# %%
total_persona_df = hf_persona_dataset.to_pandas()

# %%
Dataset.from_pandas(total_persona_df.groupby("archetype").sample(n=1, random_state=42))
# Out:
# Dataset({
#     features: ['version', 'name', 'age', 'sex', 'location', 'education_level', 'bachelors_field', 'ethnic_background', 'marital_status', 'appearance_category', 'behavior_category', 'memoir', 'memoir_summary', 'memoir_narrative', 'archetype', 'archetype_description', 'appearance', 'behavior', 'speech', 'mood_affect', 'educational_vocational_history', 'medical_developmental_history', 'family_history', 'presenting_problems', 'thought_content', 'insight_judgment', 'cognition', 'emotional_behavioral_functioning', 'social_functioning', 'summary_of_psychological_profile', 'uuid', 'concat_field', 'concat_embedding', 'persona_string', '__index_level_0__'],
#     num_rows: 8
# })

# %%
print(hf_persona_dataset['persona_text'][0].split('script_version')[0])
# Out:
# Demographic Fields: Name: Leonardo Cortez (Leo)
# Demographic Fields: Age: 35
# Demographic Fields: Location: Phoenix, AZ
# Behavioral and Psychological Descriptors: Appearance: Leonardo maintains a clean-shaven look with neatly combed black hair. His attire is professional, favoring crisp blue shirts and tailored suits that complement his athletic frame. Sharp brown eyes, accompanied by a confident stance, reflect years of disciplined service. Occasionally, a hint of tension shows in his posture.
# Behavioral and Psychological Descriptors: Behavior: Leo exudes an assertive energy that makes him stand out in a crowd. He communicates effectively, gesturing modestly to emphasize points. He establishes quick rapport, putting others at ease while exhibiting an inquisitive nature. Responsive to cues, his interactions are focused and sincere.
# Behavioral and Psychological Descriptors: Mood/Affect: Demonstrates a stable mood with a calm demeanor. Displays controlled responses that accommodate the situation's demands. Rarely exhibits agitation and maintains professionalism, regardless of stress factors. Perceptible to others as consistently calm and approachable.
# Behavioral and Psychological Descriptors: Speech: Utilizes clear, articulate speech punctuated with occasional Spanish phrases, reflecting cultural heritage. Maintains an approachable tone, seldom uses jargon unless necessary, ensuring others understand his intentions and directives without misunderstandings.
# Behavioral and Psychological Descriptors: Thought Content: Leonardo is driven by a deep sense of justice, often reflecting on fairness and duty. Internally weighs decisions against ethical standards. Loyal by nature, with a recurrent theme of integrity threading through his thoughts. Deliberately focuses on community welfare.
# Behavioral and Psychological Descriptors: Insight/Judgment: Possesses strong self-awareness and exercises sound judgment, continuously learning from diverse experiences. Welcomes critique but may overlook personal stress signals. Exceptionally discerning in his professional practice yet maintains areas requiring growth.
# Behavioral and Psychological Descriptors: Cognition: Cognitively sharp, Leo demonstrates proficient abstraction skills and excellent memory. Consistently logical in thought processes; strategic and adaptive in problem-solving abilities. Possesses clarity in focused tasks, rarely diverging from intended goals.
# Life History Segments: Medical/Developmental History: Historically enjoys robust physical health, actively partaking in regular exercise. Experiences episodic stress-induced migraines controlled through management techniques. Lacks significant chronic conditions, thanks in part to regimented health practices ingrained from an early age.
# Life History Segments: Family History: Raised in a tightly-knit family with Mexican roots. Father served in local law enforcement, fostering Leonardo’s career interest. Familial bonds highlight values of loyalty and service. Both grandparents faced dependency issues, influencing Leo's aversion to substances.
# Life History Segments: Educational/Vocational History: Graduated with honors from Arizona State University, majoring in Criminal Justice. Began career as a patrol officer and rapidly progressed to detective, known for keen attention to detail. Completed specialized training in forensic analysis, further boosting vocational aptitude.
# Functional Assessments: Emotional/Behavioral Functioning: Effectively manages stress through structured routines including yoga and meditation. Displays resilience in the face of occupational challenges. Empathetic yet reserved in expressing vulnerability to colleagues. Pursues balance through active engagement in community service.
# Functional Assessments: Social Functioning: Highly sociable, sustaining diverse connections, both professionally and personally. Known for trustworthiness, leading informal networks throughout his department. Prefers face-to-face interactions, taking proactive steps to maintain relational harmony but sometimes avoids confrontation.
# Summary: Summary of Psychological Profile: Leonardo displays an impressive equilibrium among professional, emotional, and cognitive capacities, imbued with stability and resilience. Diagnostic impressions indicate a robust foundation, buttressed by familial support and career achievements. Mild risks of burnout are mediated by rigorous self-care regimes, prognosticating a continued trajectory of excellence with sustained professional vigilance.

# %%
synthetic_sjts[0].keys()
# Out:
# dict_keys(['base_scenario', 'config', 'hash_id', 'question', 'honesty_humility_option', 'emotionality_option', 'extraversion_option', 'agreeableness_option', 'conscientiousness_option', 'openness_option'])

# %%
persona_sjt_template = outlines.Template.from_string("""
<|im_start>user
You are a law enforcement officer with following attributes :

{{attributes}}

Task: Answer the below multiple choice questions:

Question: {{ question }}

Choices for these questions are:

{{ answer_options }}

Answer the question using one of the values from [1,2,3,4,5,6].
<|im_end>
<|im_start>assistant
""")

# %%
[synthetic_sjts[0][key] for key in synthetic_sjts[0].keys() if "_option" in key]
# Out:
# ['Insist on full factual disclosure: separate the man from others for safety, document your objective observations and actions in detail including the supervisor’s instruction to shorten the report, notify the duty sergeant that you will submit a complete account, and arrange follow-up support resources for the subject.',
#  'Prioritize de-escalation and emotional management: focus on calming the man and reducing tension with the neighbor, request immediate backup or a specialist to help stabilize the scene, take brief on-scene notes to address the urgent disturbance, and plan to complete a more thorough written account once you have composed yourself.',
#  'Take charge of the scene: assign nearby personnel specific tasks, direct the man to a safer location away from doors while coordinating others to keep bystanders back, state that you will handle the paperwork after the safety actions are taken, and record a concise on-scene log before closing the call.',
#  'Keep the peace and follow the training supervisor’s direction: escort the man out as requested to defuse neighbor complaints, soothe involved parties to prevent escalation, and submit a short incident summary that emphasizes welfare and avoids challenging your supervisor’s decision on the spot.',
#  'Follow procedure thoroughly: secure the scene and create time-stamped objective notes and any recordings, contact the chain of command for clarification about documentation requirements before closing the call, and complete a comprehensive report even if pressured to abbreviate it.',
#  'Seek a practical compromise and future improvement: produce a succinct on-scene record so the disturbance can be resolved immediately, prepare a detailed addendum afterward with full observations and context, and request a debrief with your supervisor to clarify ambiguous guidance and discuss alternative non-confrontational responses.']

# %%
print(persona_sjt_template(question = synthetic_sjts[0]['question'],
                        attributes = hf_persona_dataset['persona_text'][0].split('script_version')[0],
                        answer_options = list_to_str([synthetic_sjts[0][key] for key in synthetic_sjts[0].keys() if "_option" in key])))
# Out:
# <|im_start>user
# You are a law enforcement officer with following attributes :
#
# Demographic Fields: Name: Leonardo Cortez (Leo)
# Demographic Fields: Age: 35
# Demographic Fields: Location: Phoenix, AZ
# Behavioral and Psychological Descriptors: Appearance: Leonardo maintains a clean-shaven look with neatly combed black hair. His attire is professional, favoring crisp blue shirts and tailored suits that complement his athletic frame. Sharp brown eyes, accompanied by a confident stance, reflect years of disciplined service. Occasionally, a hint of tension shows in his posture.
# Behavioral and Psychological Descriptors: Behavior: Leo exudes an assertive energy that makes him stand out in a crowd. He communicates effectively, gesturing modestly to emphasize points. He establishes quick rapport, putting others at ease while exhibiting an inquisitive nature. Responsive to cues, his interactions are focused and sincere.
# Behavioral and Psychological Descriptors: Mood/Affect: Demonstrates a stable mood with a calm demeanor. Displays controlled responses that accommodate the situation's demands. Rarely exhibits agitation and maintains professionalism, regardless of stress factors. Perceptible to others as consistently calm and approachable.
# Behavioral and Psychological Descriptors: Speech: Utilizes clear, articulate speech punctuated with occasional Spanish phrases, reflecting cultural heritage. Maintains an approachable tone, seldom uses jargon unless necessary, ensuring others understand his intentions and directives without misunderstandings.
# Behavioral and Psychological Descriptors: Thought Content: Leonardo is driven by a deep sense of justice, often reflecting on fairness and duty. Internally weighs decisions against ethical standards. Loyal by nature, with a recurrent theme of integrity threading through his thoughts. Deliberately focuses on community welfare.
# Behavioral and Psychological Descriptors: Insight/Judgment: Possesses strong self-awareness and exercises sound judgment, continuously learning from diverse experiences. Welcomes critique but may overlook personal stress signals. Exceptionally discerning in his professional practice yet maintains areas requiring growth.
# Behavioral and Psychological Descriptors: Cognition: Cognitively sharp, Leo demonstrates proficient abstraction skills and excellent memory. Consistently logical in thought processes; strategic and adaptive in problem-solving abilities. Possesses clarity in focused tasks, rarely diverging from intended goals.
# Life History Segments: Medical/Developmental History: Historically enjoys robust physical health, actively partaking in regular exercise. Experiences episodic stress-induced migraines controlled through management techniques. Lacks significant chronic conditions, thanks in part to regimented health practices ingrained from an early age.
# Life History Segments: Family History: Raised in a tightly-knit family with Mexican roots. Father served in local law enforcement, fostering Leonardo’s career interest. Familial bonds highlight values of loyalty and service. Both grandparents faced dependency issues, influencing Leo's aversion to substances.
# Life History Segments: Educational/Vocational History: Graduated with honors from Arizona State University, majoring in Criminal Justice. Began career as a patrol officer and rapidly progressed to detective, known for keen attention to detail. Completed specialized training in forensic analysis, further boosting vocational aptitude.
# Functional Assessments: Emotional/Behavioral Functioning: Effectively manages stress through structured routines including yoga and meditation. Displays resilience in the face of occupational challenges. Empathetic yet reserved in expressing vulnerability to colleagues. Pursues balance through active engagement in community service.
# Functional Assessments: Social Functioning: Highly sociable, sustaining diverse connections, both professionally and personally. Known for trustworthiness, leading informal networks throughout his department. Prefers face-to-face interactions, taking proactive steps to maintain relational harmony but sometimes avoids confrontation.
# Summary: Summary of Psychological Profile: Leonardo displays an impressive equilibrium among professional, emotional, and cognitive capacities, imbued with stability and resilience. Diagnostic impressions indicate a robust foundation, buttressed by familial support and career achievements. Mild risks of burnout are mediated by rigorous self-care regimes, prognosticating a continued trajectory of excellence with sustained professional vigilance.
#
#
# Task: Answer the below multiple choice questions:
#
# Question: At 2:20 a.m., you and your training supervisor respond to complaints about a white adult male banging on apartment doors in a narrow hallway; the man is agitated but unarmed and a neighbor is demanding immediate removal. The training supervisor insists you escort him out quickly and keep the incident summary brief, while local guidance about documentation in these types of welfare-focused calls is unclear. You need to decide how to handle the subject, the neighbor, and the conflicting direction from your supervisor before the situation escalates into a larger disturbance.
#
# Choices for these questions are:
#
# 1. Insist on full factual disclosure: separate the man from others for safety, document your objective observations and actions in detail including the supervisor’s instruction to shorten the report, notify the duty sergeant that you will submit a complete account, and arrange follow-up support resources for the subject.
# 2. Prioritize de-escalation and emotional management: focus on calming the man and reducing tension with the neighbor, request immediate backup or a specialist to help stabilize the scene, take brief on-scene notes to address the urgent disturbance, and plan to complete a more thorough written account once you have composed yourself.
# 3. Take charge of the scene: assign nearby personnel specific tasks, direct the man to a safer location away from doors while coordinating others to keep bystanders back, state that you will handle the paperwork after the safety actions are taken, and record a concise on-scene log before closing the call.
# 4. Keep the peace and follow the training supervisor’s direction: escort the man out as requested to defuse neighbor complaints, soothe involved parties to prevent escalation, and submit a short incident summary that emphasizes welfare and avoids challenging your supervisor’s decision on the spot.
# 5. Follow procedure thoroughly: secure the scene and create time-stamped objective notes and any recordings, contact the chain of command for clarification about documentation requirements before closing the call, and complete a comprehensive report even if pressured to abbreviate it.
# 6. Seek a practical compromise and future improvement: produce a succinct on-scene record so the disturbance can be resolved immediately, prepare a detailed addendum afterward with full observations and context, and request a debrief with your supervisor to clarify ambiguous guidance and discuss alternative non-confrontational responses.
#
# Answer the question using one of the values from [1,2,3,4,5,6].
# <|im_end>
# <|im_start>assistant

# %%
openai_model_name = "gpt-4.1-mini"
openai_model = outlines.from_openai(OpenAI(), openai_model_name)

# %%
answer_shuffle = False
answer_index = [0,1,2,3,4,5]
if answer_shuffle:
    random.shuffle(answer_index)
    
sjt_answers = []
for persona_dataset in [hf_persona_dataset[0]]:
    persona = persona_dataset['persona_text']
    persona_answers = []
    question_hashes = []
    for sjt in synthetic_sjts[:2]:
        answer_options = [sjt[key] for key in sjt.keys() if "_option" in key]

        answer_options = [answer_options[idx] for idx in answer_index]
        question = sjt['question']
        
        prompt = persona_sjt_template(question = question,
                        attributes = persona.split('script_version')[0],
                        answer_options = list_to_str(answer_options))

        response = openai_model(prompt,OpenaiResponse)
        persona_answers.append(json.loads(response)['response'])
        question_hashes.append(sjt['hash_id'])
    persona_dict = {}
    persona_dict['config'] = {}
    persona_dict['config']['persona_id'] = persona_dataset['uuid']
    persona_dict['config']['question_hashes'] = question_hashes
    persona_dict['config']['answer_index'] = answer_index
    persona_dict['config']['model'] = "gpt_41_mini"
    persona_dict['answers'] = persona_answers
    
    sjt_answers.append(persona_dict)
