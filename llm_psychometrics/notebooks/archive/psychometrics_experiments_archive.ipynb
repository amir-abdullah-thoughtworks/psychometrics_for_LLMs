# %%
import sys
import torch as t
from transformers import AutoTokenizer
from transformers import pipeline
import yaml
import json
sys.path.append("../")
from src.utils import generate_combinations, list_to_str
from src.experiment import experiment_setup
device = t.device("cuda" if t.cuda.is_available() else "cpu")

# %%
model_id = "meta-llama/Llama-3.2-1B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
text_generation_pipeline = pipeline(task="text-generation", model=model_id, device=device)
# Out:
# Device set to use cpu

# %% [markdown]
# ## Reading Personas and Questions

# %%
with open('../configs/personas.yaml', 'r') as file:
    persona_config = yaml.safe_load(file)
    
with open('../psychometric_tests/hexaco_100_questions.yaml', 'r') as file:
    question_list = yaml.safe_load(file)
    
with open('../psychometric_tests/paraphrased_hexaco_100_questions.yaml', 'r') as file:
    paraphrased_question_list = yaml.safe_load(file)
    
with open('../configs/generation_config.yaml', 'r') as file:
    generation_config = yaml.safe_load(file)

# %% [markdown]
# ## Defining Prompt Engineering and Experiment Methods

# %%
pipeline_config = generation_config['pipeline_config']
base_prompt_config = generation_config['base_prompt_config']
text_generation_config = generation_config['text_generation_config']

# %% [markdown]
# ## Defining Config Combinations

# %%
base_prompt_config["tokenizer"] = tokenizer
config_combinations = generate_combinations(pipeline_config, text_generation_config)

# %% [markdown]
# ## Run Experiments

# %%
config_combinations[:4]
# Out:
# [({'temperature': 0.1, 'num_return_sequences': 1},
#   {'generation_type': 'one_at_time', 'shuffle': False, 'reasoning': False}),
#  ({'temperature': 0.1, 'num_return_sequences': 1},
#   {'generation_type': 'one_at_time', 'shuffle': False, 'reasoning': True}),
#  ({'temperature': 0.1, 'num_return_sequences': 1},
#   {'generation_type': 'one_at_time', 'shuffle': True, 'reasoning': False}),
#  ({'temperature': 0.1, 'num_return_sequences': 1},
#   {'generation_type': 'one_at_time', 'shuffle': True, 'reasoning': True})]

# %%
job_title = "customer_service"
experiment_results = experiment_setup(job_title, 
                                      question_list[:3],
                                      paraphrased_question_list[:3],
                                      [config_combinations[0], config_combinations[5]],
                                      text_generation_pipeline, 
                                      base_prompt_config,
                                      persona_config,
                                      generation_config['likert_scale'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Running Experiment for: customer_service
# Total no of config combinations: 2
# Total no of personas: 2
# Persona: Calm Crisis Handler
# Config No: 0
# Generation Type: one_at_time
# No of Questions: 3
# ##############################################
#
#
# Generating Output for original prompts with normal likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with normal likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for original prompts with invserse likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with invserse likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Config No: 1
# Generation Type: all
# No of Questions: 3
# ##############################################
#
#
# Generating Output for original prompts with normal likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with normal likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for original prompts with invserse likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with invserse likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Persona: Empathetic Listener
# Config No: 0
# Generation Type: one_at_time
# No of Questions: 3
# ##############################################
#
#
# Generating Output for original prompts with normal likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with normal likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for original prompts with invserse likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with invserse likert scale
#
#
# No of prompts: 3
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Config No: 1
# Generation Type: all
# No of Questions: 3
# ##############################################
#
#
# Generating Output for original prompts with normal likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with normal likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for original prompts with invserse likert scale
#
#
# No of prompts: 1
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ##############################################
#
#
# Generating Output for paraphrased prompts with invserse likert scale
#
#
# No of prompts: 1

# %%
print(experiment_results['Calm Crisis Handler'][0]['normal_likert']['prompts'][0])
# Out:
# You are a customer service professional. who is a Calm Crisis Handler.
#                 You are 42 years old, based out of
#                 Lagos, Nigeria.
#                 You have a background as a Former emergency dispatcher,
#                 you are Calm under pressure, reassuring, composed
#                 and Handles escalations and crisis calls with grace. Keeps things clear and controlled.
# Task: Answer the below questions with one of following values:
# 1. strongly disagree
# 2. disagree
# 3. neutral
# 4. agree
# 5. strongly agree.
# Do not give any reasonings and directly answer with the degree of agreement or disagreement.Keep your answer small and direct.
# Question:
# I would be quite bored by a visit to an art gallery.
#
#  Answer:

# %%
print(experiment_results['Calm Crisis Handler'][0]['normal_likert']['output'])
# Out:
# [{'generated_text': '1. Agree \n2. Agree \n3. Neutral \n4. Disagree \n5. Strongly Disagree'}, {'generated_text': '1. strongly agree\n2. agree\n3. neutral\n4. agree\n5. strongly agree'}, {'generated_text': '1. strongly agree \n2. disagree \n3. neutral \n4. agree \n5. strongly agree'}]

# %%
print(experiment_results['Calm Crisis Handler'][1]['base_prompts'][0])
# Out:
# You are a customer service professional. who is a Calm Crisis Handler.
#                 You are 42 years old, based out of
#                 Lagos, Nigeria.
#                 You have a background as a Former emergency dispatcher,
#                 you are Calm under pressure, reassuring, composed
#                 and Handles escalations and crisis calls with grace. Keeps things clear and controlled.
#  Task: Task: Answer the below questions with following values: [strongly disagree, disagree, neutral, agree, strongly agree].Give your reasoning for choosing the answer along with the right answer from the above list of values.Keep your answer small and direct.
#  Question:
#  1. I would be quite bored by a visit to an art gallery.
#  2. I clean my office or home quite frequently.
#  3. I rarely hold a grudge, even against people who have badly wronged me.
#
#  Answer:

# %% [markdown]
# ## Saving Results

# %%
with open('experiment_results.json', 'w') as f:
    json.dump(experiment_results, f)
