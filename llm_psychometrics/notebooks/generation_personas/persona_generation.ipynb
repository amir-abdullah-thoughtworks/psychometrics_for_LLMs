# %%
import os

# %%
src_dir = "/Users/amirabdullah/work/codes/psychometrics_for_LLMs/llm_psychometrics/src"
configs_dir = "/Users/amirabdullah/work/codes/psychometrics_for_LLMs/llm_psychometrics/configs"
demographics_dir = "/Users/amirabdullah/work/codes/psychometrics_for_LLMs/llm_psychometrics/data/demographics"
os.chdir(src_dir)

# %%
from persona_generation.pydantic_persona_generation_v2 import run_batch, PersonaGenerator
# Out:
# /Users/amirabdullah/work/venvs/psychometrics/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
generator = PersonaGenerator(
        populated_seeds_yaml=f"{configs_dir}/populated_police_seeds.yaml",
    balanced_officers_csv=f"{demographics_dir}/balanced_us_police_officers.csv", version="v12")

# %%
generator.generate_one(4497)

# %%
! pwd

# %%
version = "v12"
run_batch(
    populated_seeds_yaml=f"{configs_dir}/populated_police_seeds.yaml",
    balanced_officers_csv=f"{demographics_dir}/balanced_us_police_officers.csv",
    count=8500,
    hf_repo_id="thoughtworks/psychometric_personas",
    version=version,
    out_jsonl=f"{version}.jsonl"
)
# Out:
# Found 621 existing keys
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8500/8500 [00:00<00:00, 58237.57it/s]
# Pre-skip (already in ./v12.jsonl): 621
# Scheduling 7879 new generations out of requested 8500.
# Wrote 7879 personas to v12.jsonl (skipped 0, pre-skipped 621).
# Pushing to HF dataset: thoughtworks/psychometric_personas (append + dedupe + overwrite)
# README.md:   0%|          | 0.00/1.69k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/271k [00:00<?, ?B/s]
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Push complete.
